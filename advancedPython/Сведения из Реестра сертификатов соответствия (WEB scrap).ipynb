# %%
import requests
import json
#from bs4 import BeautifulSoup

# %%
user_id = 12345
url = 'https://pub.fsa.gov.ru/api/v1/rds/common/declarations/get'
start_page = 100
token = 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJpc3MiOiJhYjU2NDkwNi1mYTc4LTRkMzgtYmFkOS1iNWQyYWE4NmEyNWUiLCJzdWIiOiJhbm9ueW1vdXMiLCJleHAiOjE2Njc4NjAyNjl9.mYIt_9MtY8SU07No07im62h1ZuPzwubPNuDhcV3ozOC_qKAqVZ_HDXNcAKlJvQaQNSAcr9sexjqrNqVrERf1QQ'

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',    
    'Authorization':'Bearer ',    
    'Cookie':'JSESSIONID=E6AE642D73F41907EFEE24E0EFFFB032',    
    'Accept':'application/json, text/plain, */*',
    'Content-Type':'application/json',  
    'Content-Length':'593',    
    'Content-Type':'application/json' 
   }


rqdata = {"size":10,
          "page":10,
          "filter":{"status":[6],"idDeclType":[2],"idCertObjectType":[3],
                    "idProductType":[],"idGroupRU":[],"idGroupEEU":[],"idTechReg":[],"idApplicantType":[],
                    "regDate":{"minDate":None,"maxDate":None},"endDate":{"minDate":"2023-06-01","maxDate":"2023-06-30"},
                    "columnsSearch":[{"name":"number","search":"","type":8,"translated":False}],
                    "idProductOrigin":["380"],"idProductEEU":[],"idProductRU":[],"idDeclScheme":[],"awaitForApprove":None,
                    "awaitOperatorCheck":None,"editApp":None,
                    "violationSendDate":None,"isProtocolInvalid":None},"columnsSort":[{"column":"declDate","sort":"DESC"}]}
rqdata['page'] = start_page

rj = json.dumps(rqdata).replace(' ','')
data_length = len(rj) 
print(rj)
print(data_length)

headers['Content-Length'] = str(data_length)
headers['Authorization'] = token

print(headers)    
response = requests.post(url,json=rqdata,  headers = headers,verify=False) #,verify=False
#r = requests.get(url)
#sp = BeautifulSoup(r.content, "html.parser")
#print(sp)
# Out:
# {"size":10,"page":100,"filter":{"status":[6],"idDeclType":[2],"idCertObjectType":[3],"idProductType":[],"idGroupRU":[],"idGroupEEU":[],"idTechReg":[],"idApplicantType":[],"regDate":{"minDate":null,"maxDate":null},"endDate":{"minDate":"2023-06-01","maxDate":"2023-06-30"},"columnsSearch":[{"name":"number","search":"","type":8,"translated":false}],"idProductOrigin":["380"],"idProductEEU":[],"idProductRU":[],"idDeclScheme":[],"awaitForApprove":null,"awaitOperatorCheck":null,"editApp":null,"violationSendDate":null,"isProtocolInvalid":null},"columnsSort":[{"column":"declDate","sort":"DESC"}]}
# 593
# ...

# %%
print(response)
response.json()
# Out:
# <Response [200]>
# {'items': [{'id': 14447249,
#    'idStatus': 6,
#    'number': 'ЕАЭС N RU Д-IT.РА01.В.47299/20',
#    'declDate': '2020-06-05',
#    'declEndDate': '2023-06-04',
#    'declDraftDate': '2020-06-05',
#    'technicalReglaments': 'О безопасности продукции легкой промышленности',
#    'group': 'Изделия платочно-шарфовые (шарфы, платки, косынки)',
#    'productSingleList': '',
#    'declType': 'Декларация о соответствии требованиям технического регламента Евразийского экономического союза (технического регламента Таможенного союза)',
#    'declObjectType': 'Серийный выпуск',
#    'awaitForApprove': 'Нет',
#    'unpublishedChanges': None,
#    'editApp': 'Нет',
#    'idApplicantLegalSubjectType': 1,
#    'applicantLegalSubjectType': 'Юридическое лицо',
#    'applicantType': 'Уполномоченное изготовителем лицо',
#    'applicantName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГРИНВИЛЛ"',
# ...

# %%
rd = response.json()
docs = rd['items']
print(len(docs))
print(docs[0])
# Out:
# 10
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
pd.options.display.float_format = '{:.1f}'.format

# %%
df = pd.DataFrame(docs)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 44 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   id                                       10 non-null     int64
#  1   idStatus                                 10 non-null     int64
#  2   number                                   10 non-null     object
#  3   declDate                                 10 non-null     object
#  4   declEndDate                              10 non-null     object
#  5   declDraftDate                            10 non-null     object
#  6   technicalReglaments                      10 non-null     object
#  7   group                                    10 non-null     object
#  8   productSingleList                        10 non-null     object
#  9   declType                                 10 non-null     object
# ...

# %%
df.sample(6)
# Out:
#          id  idStatus                          number    declDate declEndDate  \
# 9  14448695         6  ЕАЭС N RU Д-IT.НВ32.В.08937/20  2020-06-05  2023-06-04
# 0  14447249         6  ЕАЭС N RU Д-IT.РА01.В.47299/20  2020-06-05  2023-06-04
# 1  14447377         6  ЕАЭС N RU Д-IT.АЮ97.В.08362/20  2020-06-05  2023-06-04
# 5  14447829         6  ЕАЭС N RU Д-IT.АД65.В.12559/20  2020-06-05  2023-06-04
# 8  14448645         6  ЕАЭС N RU Д-IT.НВ32.В.08933/20  2020-06-05  2023-06-04
# 4  14447677         6  ЕАЭС N RU Д-IT.ПФ02.В.23014/20  2020-06-05  2023-06-04
#
#   declDraftDate                                technicalReglaments  \
# 9    2020-06-05  Требования безопасности пищевых добавок, арома...
# 0    2020-06-05     О безопасности продукции легкой промышленности
# 1    2020-06-05  Технический регламент на масложировую продукци...
# 5    2020-06-05  Требования безопасности пищевых добавок, арома...
# 8    2020-06-05  Требования безопасности пищевых добавок, арома...
# ...

# %% [raw]
# all_championship_standings = pd.DataFrame()
#
# all_championship_standings = pd.concat([all_championship_standings, pd.DataFrame([current_round])],join='outer', ignore_index=True)
